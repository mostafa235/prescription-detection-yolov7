# %%
import os
import tkinter as tk
from tkinter import filedialog
from PIL import ImageTk, Image
import subprocess
import re

def get_output(string):

    # Extract the classes from the string
    pattern = r"\d+\s+([a-zA-Z]+)"
    matches = re.findall(pattern, string)

    classes = matches[:9]  # Get the first 9 matches

    print(classes)

def run_yolov5(file_path):
    command = f'python detect.py --weights best.pt --conf 0.25 --img-size 640 --source "{file_path}" --no-trace'
    try:
        result = subprocess.check_output(command, shell=True).decode('utf-8')
        get_output(result)  # Print the output
        
        # Get the path to the folder with the maximum number in './runs/detect'
        folder_path = get_max_folder_path('./runs/detect')
        
        # Get the image name from the folder
        image_name = get_image_name(folder_path)
        
        # Get the full image path
        image_path = os.path.join(folder_path, image_name)
        
        # Display the image
        display_image(image_path)
    except subprocess.CalledProcessError as e:
        error_message = f"Error: Command '{command}' returned non-zero exit status {e.returncode}"
        print(error_message)

def get_max_folder_path(directory):
    folders = [folder for folder in os.listdir(directory) if os.path.isdir(os.path.join(directory, folder))]
    max_folder = max(folders, key=lambda x: int(x[3:]) if x[3:].isdigit() else -1)
    return os.path.join(directory, max_folder)

def get_image_name(folder_path):
    files = [file for file in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, file))]
    image_files = [file for file in files if file.lower().endswith(('.jpg', '.jpeg', '.png'))]
    if image_files:
        return image_files[0]
    else:
        return ''

def display_image(image_path):
    # Open the image using PIL
    img = Image.open(image_path)

    # Resize the image if needed
    img = img.resize((400, 400))

    # Create a Tkinter-compatible image object
    img_tk = ImageTk.PhotoImage(img)

    # Create a label in the Tkinter window to display the image
    image_label.config(image=img_tk)
    image_label.image = img_tk

def select_image():
    file_path = filedialog.askopenfilename(filetypes=[("Image Files", "*.jpg *.jpeg *.png")])
    if file_path:
        run_yolov5(file_path)

# Create the tkinter window
window = tk.Tk()

# Create a button to select the image
select_button = tk.Button(window, text="Select Image", command=select_image)
select_button.pack()

# Create a label to display the image
image_label = tk.Label(window)
image_label.pack()

# Start the tkinter event loop
window.mainloop()
# Out:
# ['antinal', 'muco', 'panadol', 'other', 'telfast', 'maalox', 'concor', 'colona', 'cidophage']

# %%
import tkinter as tk
import subprocess

def run_yolov5(file_path):
    command = f'python detect.py --weights best.pt --conf 0.25 --img-size 640 --source "{file_path}" --no-trace'
    try:
        result = subprocess.check_output(command, shell=True).decode('utf-8')
        print(result)
        # Update the tkinter GUI with the result
        result_label.config(text=result)
    except subprocess.CalledProcessError as e:
        error_message = f"Error: Command '{command}' returned non-zero exit status {e.returncode}"
        print(error_message)
        # Update the tkinter GUI with the error message
        result_label.config(text=error_message)

def select_image():
    file_path = filedialog.askopenfilename(filetypes=[("Image Files", "*.jpg *.jpeg *.png")])
    if file_path:
        run_yolov5(file_path)

# Create the tkinter window
window = tk.Tk()

# Create a button to select the image
select_button = tk.Button(window, text="Select Image", command=select_image)
select_button.pack()

# Create a label to display the result
result_label = tk.Label(window, text="")
result_label.pack()

# Start the tkinter event loop
window.mainloop()
# Out:
# Namespace(weights=['best.pt'], source='C:/Users/dell/Desktop/read prescription/yolov7-main/data/trian/images/1686001767282.jpg', img_size=640, conf_thres=0.25, iou_thres=0.45, device='', view_img=False, save_txt=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=True, save_conf=False, fourcc='mp4v')
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# 640x512 1 antinal, 1 muco, 1 panadol, 2 others, 1 telfast, 1 maalox, 1 concor, 1 colona, 1 cidophage, Done. (0.198s)
# Done. (0.252s)

# %%
import tkinter as tk
import subprocess

def run_yolov5(file_path):
    command = f'python detect.py --weights best.pt --conf 0.25 --img-size 640 --source "{file_path}" --no-trace'
    try:
        result = subprocess.check_output(command, shell=True).decode('utf-8')
        print(result)
        # Update the tkinter GUI with the result
        result_label.config(text=result)
    except subprocess.CalledProcessError as e:
        error_message = f"Error: Command '{command}' returned non-zero exit status {e.returncode}"
        print(error_message)
        # Update the tkinter GUI with the error message
        result_label.config(text=error_message)

def select_image():
    file_path = filedialog.askopenfilename(filetypes=[("Image Files", "*.jpg *.jpeg *.png")])
    if file_path:
        run_yolov5(file_path)

# Create the tkinter window
window = tk.Tk()

# Create a button to select the image
select_button = tk.Button(window, text="Select Image", command=select_image)
select_button.pack()

# Create a label to display the result
result_label = tk.Label(window, text="")
result_label.pack()

# Start the tkinter event loop
window.mainloop()
# Out:
# Namespace(weights=['best.pt'], source='C:/Users/dell/Desktop/read prescription/yolov7-main/data/trian/images/1686001767275.jpg', img_size=640, conf_thres=0.25, iou_thres=0.45, device='', view_img=False, save_txt=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=True, save_conf=False, fourcc='mp4v')
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# 640x480 1 antinal, 1 muco, 1 panadol, 1 other, 1 telfast, 1 maalox, 1 concor, 1 colona, 1 cidophage, Done. (0.187s)
# Done. (0.249s)

# %%
import tkinter as tk
from tkinter import filedialog
import subprocess
from PIL import Image, ImageTk
import io

def run_yolov5(file_path):
    command = f'python detect.py --weights best.pt --conf 0.25 --img-size 640 --source "{file_path}" --no-trace'
    try:
        result = subprocess.check_output(command, shell=True)
        # Get the resulting image bytes
        result_image_bytes = get_result_image_bytes(file_path)
        if result_image_bytes:
            # Display the resulting image in tkinter
            display_image(result_image_bytes)
    except subprocess.CalledProcessError as e:
        error_message = f"Error: Command '{command}' returned non-zero exit status {e.returncode}"
        print(error_message)

def get_result_image_bytes(image_path):
    # Modify this function based on the location and naming pattern
    # of the resulting image file generated by the detect.py script
    image_dir = os.path.dirname(image_path)
    image_name = os.path.basename(image_path)
    result_image_name = image_name.replace('.jpg', '_result.jpg')
    result_image_path = os.path.join(image_dir, result_image_name)
    if os.path.isfile(result_image_path):
        with open(result_image_path, 'rb') as image_file:
            return image_file.read()
    return None

def display_image(image_bytes):
    # Load the image from bytes
    img = Image.open(io.BytesIO(image_bytes))
    img.thumbnail((400, 400))

    # Convert the image to PhotoImage format supported by tkinter
    img_tk = ImageTk.PhotoImage(img)

    # Create a label to display the resulting image
    image_label = tk.Label(window, image=img_tk)
    image_label.pack()

    # Update the tkinter window to display the image
    window.update()

def select_image():
    file_path = filedialog.askopenfilename(filetypes=[("Image Files", "*.jpg *.jpeg *.png")])
    if file_path:
        run_yolov5(file_path)

# Create the tkinter window
window = tk.Tk()

# Create a button to select the image
select_button = tk.Button(window, text="Select Image", command=select_image)
select_button.pack()

# Start the tkinter event loop
window.mainloop()

# %%
import tkinter as tk
from tkinter import filedialog
import subprocess

def run_yolov5(file_path):
    command = f'python detect.py --weights best.pt --conf 0.25 --img-size 640 --source "{file_path}" --no-trace'
    try:
        result = subprocess.check_output(command, shell=True).decode('utf-8')
        print(result)  # Print the output
    except subprocess.CalledProcessError as e:
        error_message = f"Error: Command '{command}' returned non-zero exit status {e.returncode}"
        print(error_message)

def select_image():
    file_path = filedialog.askopenfilename(filetypes=[("Image Files", "*.jpg *.jpeg *.png")])
    if file_path:
        run_yolov5(file_path)

# Create the tkinter window
window = tk.Tk()

# Create a button to select the image
select_button = tk.Button(window, text="Select Image", command=select_image)
select_button.pack()

# Start the tkinter event loop
window.mainloop()
# Out:
# Namespace(weights=['best.pt'], source='C:/Users/dell/Desktop/read prescription/yolov7-main/data/trian/images/1686001767275.jpg', img_size=640, conf_thres=0.25, iou_thres=0.45, device='', view_img=False, save_txt=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=True, save_conf=False, fourcc='mp4v')
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# 640x480 1 antinal, 1 muco, 1 panadol, 1 other, 1 telfast, 1 maalox, 1 concor, 1 colona, 1 cidophage, Done. (0.187s)
# Done. (0.250s)

# %%
import tkinter as tk
from tkinter import filedialog
from PIL import ImageTk, Image
import subprocess

def run_yolov5(file_path):
    command = f'python detect.py --weights best.pt --conf 0.25 --img-size 640 --source "{file_path}" --no-trace'
    try:
        result = subprocess.check_output(command, shell=True).decode('utf-8')
        print(result)  # Print the output
        
        # Get the path to the resulting image
        image_path = './runs/detect/exp'  # Replace with the actual path to your image
        display_image(image_path)
    except subprocess.CalledProcessError as e:
        error_message = f"Error: Command '{command}' returned non-zero exit status {e.returncode}"
        print(error_message)

def display_image(image_path):
    # Open the image using PIL
    img = Image.open(image_path)

    # Resize the image if needed
    img = img.resize((400, 400))

    # Create a Tkinter-compatible image object
    img_tk = ImageTk.PhotoImage(img)

    # Create a label in the Tkinter window to display the image
    image_label.config(image=img_tk)
    image_label.image = img_tk

def select_image():
    file_path = filedialog.askopenfilename(filetypes=[("Image Files", "*.jpg *.jpeg *.png")])
    if file_path:
        run_yolov5(file_path)

# Create the tkinter window
window = tk.Tk()

# Create a button to select the image
select_button = tk.Button(window, text="Select Image", command=select_image)
select_button.pack()

# Create a label to display the image
image_label = tk.Label(window)
image_label.pack()

# Start the tkinter event loop
window.mainloop()
# Out:
# Namespace(weights=['best.pt'], source='C:/Users/dell/Desktop/read prescription/yolov7-main/data/trian/images/1686001767275.jpg', img_size=640, conf_thres=0.25, iou_thres=0.45, device='', view_img=False, save_txt=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=True, save_conf=False, fourcc='mp4v')
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# 640x480 1 antinal, 1 muco, 1 panadol, 1 other, 1 telfast, 1 maalox, 1 concor, 1 colona, 1 cidophage, Done. (0.187s)
# Done. (0.250s)
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "D:\anaconda\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "<ipython-input-44-12dda97bbaf9>", line 36, in select_image
#     run_yolov5(file_path)
#   File "<ipython-input-44-12dda97bbaf9>", line 14, in run_yolov5
#     display_image(image_path)
#   File "<ipython-input-44-12dda97bbaf9>", line 21, in display_image
#     img = Image.open(image_path)
#   File "D:\anaconda\lib\site-packages\PIL\Image.py", line 3131, in open
#     fp = builtins.open(filename, "rb")
# FileNotFoundError: [Errno 2] No such file or directory: 'path/to/your/image.jpg'

# %%
import os
import tkinter as tk
from tkinter import filedialog
from PIL import ImageTk, Image
import subprocess
import re

def get_output(string):

    # Extract the classes from the string
    pattern = r"\d+\s+([a-zA-Z]+)"
    matches = re.findall(pattern, string)

    classes = matches[:9]  # Get the first 9 matches

    print(classes)

def run_yolov5(file_path):
    command = f'python detect.py --weights best.pt --conf 0.25 --img-size 640 --source "{file_path}" --no-trace'
    try:
        result = subprocess.check_output(command, shell=True).decode('utf-8')
        get_output(result)  # Print the output
        
        # Get the path to the folder with the maximum number in './runs/detect'
        folder_path = get_max_folder_path('./runs/detect')
        
        # Get the image name from the folder
        image_name = get_image_name(folder_path)
        
        # Get the full image path
        image_path = os.path.join(folder_path, image_name)
        
        # Display the image
        display_image(image_path)
    except subprocess.CalledProcessError as e:
        error_message = f"Error: Command '{command}' returned non-zero exit status {e.returncode}"
        print(error_message)

def get_max_folder_path(directory):
    folders = [folder for folder in os.listdir(directory) if os.path.isdir(os.path.join(directory, folder))]
    max_folder = max(folders, key=lambda x: int(x[3:]) if x[3:].isdigit() else -1)
    return os.path.join(directory, max_folder)

def get_image_name(folder_path):
    files = [file for file in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, file))]
    image_files = [file for file in files if file.lower().endswith(('.jpg', '.jpeg', '.png'))]
    if image_files:
        return image_files[0]
    else:
        return ''

def display_image(image_path):
    # Open the image using PIL
    img = Image.open(image_path)

    # Resize the image if needed
    img = img.resize((400, 400))

    # Create a Tkinter-compatible image object
    img_tk = ImageTk.PhotoImage(img)

    # Create a label in the Tkinter window to display the image
    image_label.config(image=img_tk)
    image_label.image = img_tk

def select_image():
    file_path = filedialog.askopenfilename(filetypes=[("Image Files", "*.jpg *.jpeg *.png")])
    if file_path:
        run_yolov5(file_path)

# Create the tkinter window
window = tk.Tk()

# Create a button to select the image
select_button = tk.Button(window, text="Select Image", command=select_image)
select_button.pack()

# Create a label to display the image
image_label = tk.Label(window)
image_label.pack()

# Start the tkinter event loop
window.mainloop()
# Out:
# ['antinal', 'muco', 'panadol', 'other', 'telfast', 'maalox', 'concor', 'colona', 'cidophage']

# %%
def get_output(string)





# Extract the classes from the string
pattern = r"\d+\s+([a-zA-Z]+)"
matches = re.findall(pattern, string)

classes = matches[:9]  # Get the first 9 matches

print(classes)
# Out:
# ['antinal', 'muco', 'panadol', 'other', 'telfast', 'maalox', 'concor', 'colona', 'cidophage']
